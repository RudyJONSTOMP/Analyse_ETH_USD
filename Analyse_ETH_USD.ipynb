# %%
pip install pandas yfinance
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 30.8 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 13.3 MB/s eta 0:00:00
# ...
#   Created wheel for peewee: filename=peewee-3.17.0-cp311-cp311-macosx_10_9_x86_64.whl size=248590 sha256=7eccc8eab3a9bb02a52bfef67352199caec10881815ba8f239029fa2f7d3cf3a
#   Stored in directory: /Users/rudyj/Library/Caches/pip/wheels/02/20/23/74a10d0cd31f5d41c19b92ddf4c138ceff01b9f4675f19dbf5
# Successfully built peewee
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

# %%
symbole = "ETH-USD"

# %%
donnees_boursieres = yf.download (symbole, start="2023-06-01", end = "2023-12-22")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
donnees_boursieres
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2023-06-01  1873.914673  1887.705322  1846.227417  1862.201416  1862.201416
# 2023-06-02  1862.423706  1910.278442  1851.964722  1907.256592  1907.256592
# 2023-06-03  1907.420776  1908.822266  1885.485474  1892.412476  1892.412476
# 2023-06-04  1892.398193  1912.205688  1885.651855  1890.513550  1890.513550
# 2023-06-05  1890.417603  1890.640503  1780.211548  1811.828369  1811.828369
# ...                 ...          ...          ...          ...          ...
# 2023-12-17  2226.892578  2244.366455  2195.761719  2196.481201  2196.481201
# 2023-12-18  2195.341797  2222.019287  2120.127441  2217.273438  2217.273438
# 2023-12-19  2218.240967  2253.348877  2139.723389  2177.872559  2177.872559
# 2023-12-20  2177.239502  2263.329102  2161.218750  2201.911377  2201.911377
# 2023-12-21  2201.790039  2278.121582  2184.856689  2239.542480  2239.542480
#
#                  Volume
# Date
# ...

# %%
pip install pandas sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
#instalation du module 
pip install mysql-connector-python
# Out:
#   Cell In[57], line 2
#     pip install mysql-connector-python
#         ^
# SyntaxError: invalid syntax

# %%
# Paramètres de connexion à la base de données MySQL

nom_utilisateur = "root"
mot_de_passe = "Hito100mysql"
hote = "localhost"
base_de_donnees = "Analyse ETH_USD"
table = "cryptoETH"

# %%
# Créez une connexion à la base de données MySQL
moteur = create_engine(f"mysql+mysqlconnector://{nom_utilisateur}:{mot_de_passe}@{hote}/{base_de_donnees}")

# %%
donnees_boursieres.to_sql(name="cryptoETH",con=moteur, if_exists="replace", index ="true")
# Out:
# -1

# %%
donnees_boursieres
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2023-06-01  1873.914673  1887.705322  1846.227417  1862.201416  1862.201416
# 2023-06-02  1862.423706  1910.278442  1851.964722  1907.256592  1907.256592
# 2023-06-03  1907.420776  1908.822266  1885.485474  1892.412476  1892.412476
# 2023-06-04  1892.398193  1912.205688  1885.651855  1890.513550  1890.513550
# 2023-06-05  1890.417603  1890.640503  1780.211548  1811.828369  1811.828369
# ...                 ...          ...          ...          ...          ...
# 2023-12-17  2226.892578  2244.366455  2195.761719  2196.481201  2196.481201
# 2023-12-18  2195.341797  2222.019287  2120.127441  2217.273438  2217.273438
# 2023-12-19  2218.240967  2253.348877  2139.723389  2177.872559  2177.872559
# 2023-12-20  2177.239502  2263.329102  2161.218750  2201.911377  2201.911377
# 2023-12-21  2201.790039  2278.121582  2184.856689  2239.542480  2239.542480
#
#                  Volume
# Date
# ...
